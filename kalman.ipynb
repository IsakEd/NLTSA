# %%
from filterpy.kalman import KalmanFilter
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = np.array(np.transpose(pd.read_csv("./data_02.dat", delim_whitespace=True)))
t_meas = data[0]
y_meas = data[1]
n_meas = len(t_meas)

# %%
plt.plot(t_meas, y_meas)
plt.grid()
plt.title("Harmonic oscillator measurement")
# Out:
# Text(0.5, 1.0, 'Harmonic oscillator measurement')

# %%
w = 2*np.pi

# %%
A = np.array([[0, 1],[-w**2, 0]]) # Transition matrix
B = np.array([1],[0]) # y(t) is measured, dy/dt is not directly measured

# %%
sigma_n = 0.01

# %% [markdown]
# where A corresponds to the transition matrix from state xn to xn+1 and omega_n corresponds
# to the dynamical noise. We will consider that this noise is gaussian distributed with standard
# deviation 0.01 and zero mean. By generating a realization of this type of noise and computing
# its covariance, you may estimate Qω. Considering

# %%
def oscillator(y, t):
